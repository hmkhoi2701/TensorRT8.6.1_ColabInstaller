# %% [markdown]
# # Run the cells below (~10 mins)

# %%
# !nvidia-smi
# Out:
# Mon Jun 19 09:21:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Keep track of Ubuntu process here, you may have to respond to cell output

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/cuda-keyring_1.0-1_all.deb
# !sudo dpkg -i cuda-keyring_1.0-1_all.deb
# !sudo apt-get update
# !sudo apt-get -y install cuda
# Out:
# dpkg: error: cannot access archive 'cuda-keyring_1.0-1_all.deb': No such file or directory
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:2 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease [24.3 kB]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:7 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:9 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:16:06_PDT_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0

# %%
# !wget https://developer.nvidia.com/downloads/compute/machine-learning/tensorrt/secure/8.6.1/local_repos/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0_1.0-1_amd64.deb
# Out:
# --2023-06-19 09:32:07--  https://developer.nvidia.com/downloads/compute/machine-learning/tensorrt/secure/8.6.1/local_repos/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0_1.0-1_amd64.deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.20.126
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/machine-learning/tensorrt/secure/8.6.1/local_repos/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0_1.0-1_amd64.deb?pD8YsFr9i0n1niWsskPL-S1nRaYsgNpbV7QlmNQwgriZr8YhzrdCZjoNxP8kKmZhm7iMzH72PTgyx4X5OwYZ8sbQnolzmdmMGvhKxYnsP6UQGee_H3CMCHxLBbk9OLHKpR_5zwJLvjV1zmNH5FQCgmPRtIEAmSOkDbjQHycBTwYDQXCWI8e4b27geJ7s6yRuQIuDCOQCKWXOWVN04ErCQIRdaYV0ZLmt7ipxD3e2SXkgYRYnvdg23rQzqg== [following]
# ...

# %%
# !sudo dpkg -i "/content/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0_1.0-1_amd64.deb"

# !sudo cp /var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0/*-keyring.gpg /usr/share/keyrings/

# !sudo apt-key add /var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0/9A1EDFBA.pub
# !sudo apt-get update
# Out:
# Selecting previously unselected package nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0.
# (Reading database ... 141662 files and directories currently installed.)
# Preparing to unpack .../nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0_1.0-1_amd64.deb ...
# Unpacking nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0 (1.0-1) ...
# Setting up nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0 (1.0-1) ...
#
# The public nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0 GPG key does not appear to be installed.
# To install the key, run this command:
# sudo cp /var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0/nv-tensorrt-local-9A1EDFBA-keyring.gpg /usr/share/keyrings/
#
# OK
# Get:1 file:/var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0  InRelease [1,572 B]
# Get:1 file:/var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0  InRelease [1,572 B]
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# ...

# %%
import os
import subprocess
for file in os.listdir("/var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0/"):
  # if file.endswith("deb"):
  #   subprocess.run(["sudo", "dpkg", "-i", f"/var/nv-tensorrt-local-repo-ubuntu2004-8.6.1-cuda-12.0/{file}"])
  print(file)
# Out:
# Release.gpg
# libnvinfer-headers-plugin-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-vc-plugin8_8.6.1.6-1+cuda12.0_amd64.deb
# graphsurgeon-tf_8.6.1.6-1+cuda12.0_amd64.deb
# libnvparsers8_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-samples_8.6.1.6-1+cuda12.0_all.deb
# libnvinfer-lean8_8.6.1.6-1+cuda12.0_amd64.deb
# 9A1EDFBA.pub
# InRelease
# python3-libnvinfer-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvparsers-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-lean-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-plugin8_8.6.1.6-1+cuda12.0_amd64.deb
# python3-libnvinfer-lean_8.6.1.6-1+cuda12.0_amd64.deb
# tensorrt-libs_8.6.1.6-1+cuda12.0_amd64.deb
# tensorrt-dev_8.6.1.6-1+cuda12.0_amd64.deb
# libnvinfer-headers-dev_8.6.1.6-1+cuda12.0_amd64.deb
# nv-tensorrt-local-9A1EDFBA-keyring.gpg
# libnvonnxparsers-dev_8.6.1.6-1+cuda12.0_amd64.deb
# tensorrt_8.6.1.6-1+cuda12.0_amd64.deb
# python3-libnvinfer_8.6.1.6-1+cuda12.0_amd64.deb
# Local.md5
# Packages
# ...

# %%
# !sudo apt-get install libnvinfer8=8.6.1.6-1+cuda12.0 libnvonnxparsers8=8.6.1.6-1+cuda12.0 libnvparsers8=8.6.1.6-1+cuda12.0 libnvinfer-plugin8=8.6.1.6-1+cuda12.0 libnvinfer-dev=8.6.1.6-1+cuda12.0 libnvonnxparsers-dev=8.6.1.6-1+cuda12.0 libnvparsers-dev=8.6.1.6-1+cuda12.0 libnvinfer-plugin-dev=8.6.1.6-1+cuda12.0 python3-libnvinfer=8.6.1.6-1+cuda12.0

# !sudo apt-mark hold libnvinfer8 libnvonnxparsers8 libnvparsers8 libnvinfer-plugin8 libnvinfer-dev libnvonnxparsers-dev libnvparsers-dev libnvinfer-plugin-dev python3-libnvinfer
# !sudo apt-get install tensorrt
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libnvinfer-headers-dev libnvinfer-headers-plugin-dev libnvinfer-vc-plugin8
# The following NEW packages will be installed:
#   libnvinfer-dev libnvinfer-headers-dev libnvinfer-headers-plugin-dev
#   libnvinfer-plugin-dev libnvinfer-plugin8 libnvinfer-vc-plugin8 libnvinfer8
#   libnvonnxparsers-dev libnvonnxparsers8 libnvparsers-dev libnvparsers8
#   python3-libnvinfer
# 0 upgraded, 12 newly installed, 0 to remove and 20 not upgraded.
# Need to get 1,010 MB of archives.
# After this operation, 2,790 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvinfer-headers-dev 8.6.1.6-1+cuda12.0 [101 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvinfer8 8.6.1.6-1+cuda12.0 [492 MB]
# ...

# %%
# !dpkg-query -W tensorrt
# Out:
# tensorrt	8.6.1.6-1+cuda12.0

# %%
# !dpkg -l | grep TensorRT
# Out:
# ii  libnvinfer-bin                                    8.6.1.6-1+cuda12.0                amd64        TensorRT binaries
# hi  libnvinfer-dev                                    8.6.1.6-1+cuda12.0                amd64        TensorRT development libraries
# ii  libnvinfer-dispatch-dev                           8.6.1.6-1+cuda12.0                amd64        TensorRT development dispatch runtime libraries
# ii  libnvinfer-dispatch8                              8.6.1.6-1+cuda12.0                amd64        TensorRT dispatch runtime library
# ii  libnvinfer-headers-dev                            8.6.1.6-1+cuda12.0                amd64        TensorRT development headers
# ii  libnvinfer-headers-plugin-dev                     8.6.1.6-1+cuda12.0                amd64        TensorRT plugin headers
# ii  libnvinfer-lean-dev                               8.6.1.6-1+cuda12.0                amd64        TensorRT lean runtime libraries
# ...

# %%
import os
os.chdir("../content")

# %% [markdown]
# # Upload your files & change name in below cells

# %%
# !../usr/src/tensorrt/bin/trtexec --onnx="rtdetr18.onnx" --saveEngine=rtdetr18.trt
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8601] # ../usr/src/tensorrt/bin/trtexec --onnx=rtdetr18.onnx --saveEngine=rtdetr50.trt
# [06/19/2023-10:01:26] [I] === Model Options ===
# [06/19/2023-10:01:26] [I] Format: ONNX
# [06/19/2023-10:01:26] [I] Model: rtdetr18.onnx
# [06/19/2023-10:01:26] [I] Output:
# [06/19/2023-10:01:26] [I] === Build Options ===
# [06/19/2023-10:01:26] [I] Max batch: explicit batch
# [06/19/2023-10:01:26] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [06/19/2023-10:01:26] [I] minTiming: 1
# [06/19/2023-10:01:26] [I] avgTiming: 8
# [06/19/2023-10:01:26] [I] Precision: FP32
# [06/19/2023-10:01:26] [I] LayerPrecisions:
# [06/19/2023-10:01:26] [I] Layer Device Types:
# [06/19/2023-10:01:26] [I] Calibration:
# [06/19/2023-10:01:26] [I] Refit: Disabled
# [06/19/2023-10:01:26] [I] Version Compatible: Disabled
# [06/19/2023-10:01:26] [I] TensorRT runtime: full
# [06/19/2023-10:01:26] [I] Lean DLL Path:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/rtdetr18.trt /content/drive/MyDrive
